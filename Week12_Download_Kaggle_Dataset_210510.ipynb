# %% [markdown]
# # How to Download Kaggle Dataset for Your Colab Project
#
# 0. __Have a Kaggle account__
# 1. Create and download your Kaggle API token
# 2. Upload kaggle.json to your Colab notebook
# 3. Download dataset
# 4. Unzip dataset

# %%
# Install kaggle package

# !pip install kaggle

# %%
from google.colab import files

# %%
# Upload Kaggle API token (kaggle.json)

files.upload()

# %%
# Move token and give permission

# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download data

# !kaggle datasets download -d kunalgupta2616/flickr-8k-images-with-captions

# %%
# Unzip data

# !unzip -q flickr-8k-images-with-captions.zip

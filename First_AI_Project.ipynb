# %% [markdown]
# # Week 9 Exercise

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Transform the given image with at least 3 different methods
# Try to make it look like the below image

# %% [markdown]
# ![다운로드.png](data:image/png;base64,...)

# %%
# !wget https://i.pinimg.com/originals/21/ae/ae/21aeae8d2cae56289bd55665fb5d9b8f.jpg
# !mv 21aeae8d2cae56289bd55665fb5d9b8f.jpg example.jpg
# !rm 21aeae8d2cae56289bd55665fb5d9b8f.jpg
# Out:
# --2021-04-19 11:09:28--  https://i.pinimg.com/originals/21/ae/ae/21aeae8d2cae56289bd55665fb5d9b8f.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 199.232.76.84, 2a04:4e42:53::84
# Connecting to i.pinimg.com (i.pinimg.com)|199.232.76.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48642 (48K) [image/jpeg]
# Saving to: ‘21aeae8d2cae56289bd55665fb5d9b8f.jpg’
#
# 21aeae8d2cae56289bd 100%[===================>]  47.50K  --.-KB/s    in 0.01s
#
# 2021-04-19 11:09:28 (4.67 MB/s) - ‘21aeae8d2cae56289bd55665fb5d9b8f.jpg’ saved [48642/48642]
#
# rm: cannot remove '21aeae8d2cae56289bd55665fb5d9b8f.jpg': No such file or directory

# %%
from PIL import Image as Img
from torchvision import transforms

im = Img.open('example.jpg')

# %%
# Write your code
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=1),
    #transforms.RandomVerticalFlip(p=1),
    transforms.Grayscale(),
    transforms.RandomRotation(degrees=50, center=(40, 40))
])

# %%
transform(im)
# Out:
# <PIL.Image.Image image mode=L size=224x224 at 0x7FBC65E9A3D0>
